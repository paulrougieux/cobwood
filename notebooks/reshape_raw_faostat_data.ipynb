# %%
# Load 
from gftmx.faostat import faostat
fo = faostat.read_csv("Forestry_E_All_Data_(Normalized).zip")

# %%
fo
# Out:
#          area_code                                     area  item_code  \
# 0                2                              Afghanistan       1877
# 1                2                              Afghanistan       1877
# 2                2                              Afghanistan       1877
# 3                2                              Afghanistan       1877
# 4                2                              Afghanistan       1877
# ...            ...                                      ...        ...
# 2111434       5817  Net Food Importing Developing Countries       1683
# 2111435       5817  Net Food Importing Developing Countries       1683
# 2111436       5817  Net Food Importing Developing Countries       1683
# 2111437       5817  Net Food Importing Developing Countries       1683
# 2111438       5817  Net Food Importing Developing Countries       1683
#
#                                                       item  element_code  \
# ...

# %% [markdown]
# # Explore

# %% [markdown]
# ## Column names

# %%
fo.columns
# Out:
# Index(['area_code', 'area', 'item_code', 'item', 'element_code', 'element',
#        'year_code', 'year', 'unit', 'value', 'flag'],
#       dtype='object')

# %% [markdown]
# ## Area

# %%
fo.area.unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Anguilla', 'Antarctica', 'Antigua and Barbuda',
#        'Argentina', 'Armenia', 'Aruba', 'Australia', 'Austria',
#        'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados',
#        'Belarus', 'Belgium', 'Belgium-Luxembourg', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia (Plurinational State of)',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei Darussalam', 'Bulgaria',
#        'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon',
#        'Canada', 'Cayman Islands', 'Central African Republic', 'Chad',
#        'Chile', 'China', 'China, Hong Kong SAR', 'China, Macao SAR',
#        'China, mainland', 'China, Taiwan Province of', 'Christmas Island',
#        'Cocos (Keeling) Islands', 'Colombia', 'Comoros', 'Congo',
#        'Cook Islands', 'Costa Rica', "Côte d'Ivoire", 'Croatia', 'Cuba',
# ...

# %% [markdown]
# ## Item (product)

# %%
fo.item.unique()
# Out:
# array(['Forest products (export/import)', 'Roundwood',
#        'Roundwood, coniferous', 'Roundwood, non-coniferous', 'Wood fuel',
#        'Wood fuel, coniferous', 'Wood fuel, non-coniferous',
#        'Wood fuel, all species (export/import, 1961-2016)',
#        'Industrial roundwood', 'Industrial roundwood, coniferous',
#        'Industrial roundwood, coniferous (export/import)',
#        'Industrial roundwood, non-coniferous',
#        'Industrial roundwood, non-coniferous tropical (export/import)',
#        'Industrial roundwood, non-coniferous non-tropical (export/import)',
#        'Sawlogs and veneer logs', 'Sawlogs and veneer logs, coniferous',
#        'Sawlogs and veneer logs, non-coniferous',
#        'Other industrial roundwood',
#        'Other industrial roundwood, coniferous (production)',
#        'Other industrial roundwood, non-coniferous (production)',
#        'Wood charcoal', 'Wood chips, particles and residues',
# ...

# %% [markdown]
# ## Element

# %%
fo.element.unique()
# Out:
# array(['Import Value', 'Export Value', 'Production', 'Import Quantity',
#        'Export Quantity'], dtype=object)

# %% [markdown]
# ## Year

# %%
fo.year.unique()
# Out:
# array([1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974,
#        1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985,
#        1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996,
#        1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007,
#        2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018,
#        2019, 2020, 1961, 1962, 1963])

# %% [markdown]
# ## Unit

# %%
fo.unit.unique()
# Out:
# array(['1000 US$', 'm3', 'tonnes'], dtype=object)

# %% [markdown]
# ## Flag

# %%
fo.flag.unique()
# Out:
# array(['Im', 'F', '*', 'R', nan, 'A'], dtype=object)

# %%
fo.columns
# Out:
# Index(['area_code', 'area', 'item_code', 'item', 'element_code', 'element',
#        'year_code', 'year', 'unit', 'value', 'flag'],
#       dtype='object')
